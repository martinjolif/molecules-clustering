# %% [markdown]
# ### Libraries

# %% [markdown]
# This files use the "ESOL_delaney-processed" dataset, using method from the "On the best way to Cluster NCI-60 Molecules" article

# %%
# !pip install joblib==1.2.0
# !pip install MolVS==0.1.1
# !pip install numpy==1.23.5
# !pip install pandas==1.5.2
# !pip install Pillow==9.3.0
# !pip install pynndescent==0.5.8
# !pip install python-dateutil==2.8.2
# !pip install pytz==2022.7
# !pip install rdkit==2022.9.3
# !pip install scikit-learn==1.2.0
# !pip install scipy==1.9.3
# !pip install six==1.16.0
# !pip install threadpoolctl==3.1.0
# !pip install tqdm==4.64.1
# !pip install umap-learn==0.5.3

# %%
from rdkit import RDLogger
from rdkit import Chem
from rdkit.Chem import SaltRemover
from molvs import Standardizer
from rdkit.Chem import AllChem
from rdkit import DataStructs

from time import time
import numpy as np
import pandas as pd
import umap

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import calinski_harabasz_score, davies_bouldin_score, silhouette_score

# %% [markdown]
# ### Data preprocessing

# %%
molecules = pd.read_csv("ESOL_delaney-processed.csv", sep=",")
molecules = molecules[["smiles"]]
molecules = molecules.drop_duplicates(subset=['smiles'], ignore_index=True)
molecules
# Out:
#                                                  smiles
# 0     N#CC(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O)C...
# 1                     CC1:O:C:C:C:1C(=O)NC1:C:C:C:C:C:1
# 2                                    CC(C)=CCCC(C)=CC=O
# 3     C1:C:C:C2:C(:C:1):C:C:C1:C:2:C:C:C2:C3:C:C:C:C...
# 4                                          C1:C:C:S:C:1
# ...                                                 ...
# 1112                                    FC(F)(F)C(Cl)Br
# 1113                          CNC(=O)ON=C(SC)C(=O)N(C)C
# 1114                                  CCSCCSP(=S)(OC)OC
# 1115                                            CCC(C)C
# 1116        COP(=O)(OC)OC(=CCl)C1:C:C(Cl):C(Cl):C:C:1Cl
#
# [1117 rows x 1 columns]

# %%
n = molecules.shape[0]
mol = []
mol1 = []



for k in range(n):
    m = Chem.MolFromSmiles(molecules['smiles'][k])

    remover = SaltRemover.SaltRemover()  # remove salt
    m = remover.StripMol(m)
    s = Standardizer()  # standardize molecule
    m = s.standardize(m)

    mol.append(AllChem.GetMorganFingerprintAsBitVect(m, 2, nBits=1024))
    mol1.append(list(AllChem.GetMorganFingerprintAsBitVect(m, 2, nBits=1024)))

# %%
n = molecules.shape[0]
fps = mol
simis = []

for i in range(1, n):
    sims = DataStructs.BulkTanimotoSimilarity(fps[i], fps[:i])
    max_sims = np.max(np.array(sims))
    simis.append(max_sims)
simis.insert(0,1)
simis
# Out:
# [1,
#  0.12307692307692308,
#  0.06382978723404255,
#  0.13157894736842105,
#  0.1,
#  0.17857142857142858,
#  0.15384615384615385,
#  0.12244897959183673,
#  0.10714285714285714,
#  0.12048192771084337,
#  0.06153846153846154,
#  0.34782608695652173,
#  0.13793103448275862,
#  0.17142857142857143,
#  0.25,
#  0.08333333333333333,
#  0.2,
#  0.21739130434782608,
#  0.11904761904761904,
#  0.47058823529411764,
#  0.4074074074074074,
#  0.18421052631578946,
#  0.2222222222222222,
#  0.2558139534883721,
#  0.10714285714285714,
#  0.6153846153846154,
#  0.17777777777777778,
#  0.25,
#  0.25925925925925924,
#  0.4,
#  0.2,
#  0.6071428571428571,
#  0.2653061224489796,
#  0.15,
#  0.16279069767441862,
#  0.375,
#  0.3,
#  0.2727272727272727,
#  0.2553191489361702,
#  0.5471698113207547,
#  0.46153846153846156,
#  0.2857142857142857,
#  0.5384615384615384,
#  0.3888888888888889,
#  0.6976744186046512,
#  0.8125,
#  0.3548387096774194,
#  0.5263157894736842,
#  1.0,
#  0.35714285714285715,
#  0.717948717948718,
#  0.7441860465116279,
#  0.5555555555555556,
#  0.14285714285714285,
#  0.3888888888888889,
#  0.2727272727272727,
#  0.4411764705882353,
#  0.5789473684210527,
#  0.5833333333333334,
#  0.32,
#  0.6923076923076923,
#  0.6862745098039216,
#  0.6666666666666666,
#  0.5813953488372093,
#  0.5185185185185185,
#  0.696969696969697,
#  0.7678571428571429,
#  0.6153846153846154,
#  1.0,
#  1.0,
#  0.75,
#  0.5238095238095238,
#  0.5714285714285714,
#  0.7,
#  0.47058823529411764,
#  1.0,
#  0.29411764705882354,
#  1.0,
#  1.0,
#  0.5833333333333334,
#  0.3333333333333333,
#  0.7435897435897436,
#  0.5555555555555556,
#  0.9444444444444444,
#  0.45714285714285713,
#  0.8367346938775511,
#  0.4444444444444444,
#  0.4375,
#  1.0,
#  0.3064516129032258,
#  0.6,
#  0.6,
#  0.7222222222222222,
#  0.625,
#  0.7916666666666666,
#  0.575,
#  0.6571428571428571,
#  0.6153846153846154,
#  0.6153846153846154,
#  0.5555555555555556,
#  0.47619047619047616,
#  0.38461538461538464,
#  0.5,
#  0.8235294117647058,
#  0.5,
#  0.6,
#  0.2857142857142857,
#  0.7142857142857143,
#  ...]

# %%
df_tanimoto['Tanimoto similarity'] = simis
outlier_cutoff = 0.5
df_tanimoto['outlier'] = np.where(df_tanimoto['Tanimoto similarity'] <= outlier_cutoff, True, False)
df_nonoutliers = df_tanimoto[df_tanimoto.loc[:, 'outlier'] == False]

df_nonoutliers
# Out:
#                                                  smiles  Cluster_ID  \
# 0     N#CC(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O)C...           0
# 25                                             CCCCCCCO           5
# 31                             CCOP(=S)(OCC)SCSC(C)(C)C           2
# 39                                             CCCCCCCI           5
# 45                                           CCCCCC(C)O           5
# ...                                                 ...         ...
# 1107                                      CC(=O)OCC(C)C           2
# 1109  ClC1:C:C:C(C2:C(Cl):C:C(Cl):C(Cl):C:2Cl):C(Cl)...           1
# 1111                      CC1:C:C:C:C([N+](=O)[O-]):C:1           1
# 1114                                  CCSCCSP(=S)(OC)OC           2
# 1115                                            CCC(C)C           5
#
#       Tanimoto similarity  outlier
# 0                1.000000    False
# 25               0.615385    False
# 31               0.607143    False
# 39               0.615385    False
# 45               0.941176    False
# ...                   ...      ...
# 1107             0.565217    False
# 1109             0.590909    False
# 1111             0.695652    False
# 1114             0.666667    False
# 1115             0.545455    False
#
# [500 rows x 4 columns]

# %%
n = df_nonoutliers.shape[0]
new_index = []
for k in range(n):
    new_index.append(k)
new_index

df_nonoutliers.index = new_index
df_nonoutliers
# Out:
#                                                 smiles  Cluster_ID  \
# 0    N#CC(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O)C...           0
# 1                                             CCCCCCCO           5
# 2                             CCOP(=S)(OCC)SCSC(C)(C)C           2
# 3                                             CCCCCCCI           5
# 4                                           CCCCCC(C)O           5
# ..                                                 ...         ...
# 495                                      CC(=O)OCC(C)C           2
# 496  ClC1:C:C:C(C2:C(Cl):C:C(Cl):C(Cl):C:2Cl):C(Cl)...           1
# 497                      CC1:C:C:C:C([N+](=O)[O-]):C:1           1
# 498                                  CCSCCSP(=S)(OC)OC           2
# 499                                            CCC(C)C           5
#
#      Tanimoto similarity  outlier
# 0               1.000000    False
# 1               0.615385    False
# 2               0.607143    False
# 3               0.615385    False
# 4               0.941176    False
# ..                   ...      ...
# 495             0.565217    False
# 496             0.590909    False
# 497             0.695652    False
# 498             0.666667    False
# 499             0.545455    False
#
# [500 rows x 4 columns]

# %%
n = df_nonoutliers.shape[0]
nonoutliers = []
nonoutliers1 = []

for k in range(n):
    m = Chem.MolFromSmiles(df_nonoutliers['smiles'][k])

    remover = SaltRemover.SaltRemover()  # remove salt
    m = remover.StripMol(m)
    s = Standardizer()  # standardize molecule
    m = s.standardize(m)

    nonoutliers.append(AllChem.GetMorganFingerprintAsBitVect(m, 2, nBits=1024))
    nonoutliers1.append(list(AllChem.GetMorganFingerprintAsBitVect(m, 2, nBits=1024)))

# %% [markdown]
# ### Clustering

# %%
sample = nonoutliers1

# %%
t0 = time()
x_red = umap.UMAP(n_neighbors=100, min_dist=0.0, n_components=2, metric='jaccard',
                  random_state=42).fit_transform(sample)

clustering = AgglomerativeClustering(linkage='ward', n_clusters=6)
clustering.fit(x_red)
tf = time() - t0
# Out:
# /Users/mjolif/anaconda3/lib/python3.11/site-packages/umap/umap_.py:1802: UserWarning: gradient function is not yet implemented for jaccard distance metric; inverse_transform will be unavailable
#   warn(

# %%
def assign_cluster_id(df_data, cluster_id):
    df_data['Cluster_ID'] = cluster_id.labels_
    return df_data

# %%
df_clusters = assign_cluster_id(df_nonoutliers, clustering)
df_clusters
# Out:
# /var/folders/_t/26vz4yhd2lqb2866qhkw8htm0000gn/T/ipykernel_3373/3228663661.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Cluster_ID'] = cluster_id.labels_
#                                                 smiles  Cluster_ID  \
# 0    N#CC(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O)C...           2
# 1                                             CCCCCCCO           0
# 2                             CCOP(=S)(OCC)SCSC(C)(C)C           0
# 3                                             CCCCCCCI           0
# 4                                           CCCCCC(C)O           0
# ..                                                 ...         ...
# 495                                      CC(=O)OCC(C)C           0
# 496  ClC1:C:C:C(C2:C(Cl):C:C(Cl):C(Cl):C:2Cl):C(Cl)...           3
# 497                      CC1:C:C:C:C([N+](=O)[O-]):C:1           5
# 498                                  CCSCCSP(=S)(OC)OC           0
# 499                                            CCC(C)C           0
#
#      Tanimoto similarity  outlier
# 0               1.000000    False
# 1               0.615385    False
# 2               0.607143    False
# 3               0.615385    False
# 4               0.941176    False
# ..                   ...      ...
# 495             0.565217    False
# 496             0.590909    False
# 497             0.695652    False
# 498             0.666667    False
# 499             0.545455    False
#
# [500 rows x 4 columns]

# %%
s1 = silhouette_score(x_red, clustering.labels_, metric='euclidean')
c1 = calinski_harabasz_score(x_red, clustering.labels_)
d1 = davies_bouldin_score(x_red, clustering.labels_)

# %%
df_metrics = pd.DataFrame(data=[[tf, s1, c1, d1, 6, "UMAP & Agglomerative Clustering", "Just non outliers molecules", outlier_cutoff]], columns=['Time for UMAP & Clustering', 'Silhouette', 'CH score', 'DB score', "Number of Clusters", "Method", "All Molecules", "Outlier Cutoff"])
df_metrics
# Out:
#    Time for UMAP & Clustering  Silhouette     CH score  DB score  \
# 0                    2.942214    0.576074  1273.043059  0.567648
#
#    Number of Clusters                           Method  \
# 0                   6  UMAP & Agglomerative Clustering
#
#                  All Molecules  Outlier Cutoff
# 0  Just non outliers molecules             0.5

# %%
sample1 = mol1
t0 = time()
x_red = umap.UMAP(n_neighbors=100, min_dist=0.0, n_components=2, metric='jaccard',
                  random_state=42).fit_transform(sample1)

clustering = AgglomerativeClustering(linkage='ward', n_clusters=7)
clustering.fit(x_red)
tf = time() - t0
# Out:
# /Users/mjolif/anaconda3/lib/python3.11/site-packages/umap/umap_.py:1802: UserWarning: gradient function is not yet implemented for jaccard distance metric; inverse_transform will be unavailable
#   warn(

# %%
df_clusters = assign_cluster_id(molecules, clustering)
df_clusters
# Out:
#                                                  smiles  Cluster_ID
# 0     N#CC(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O)C...           0
# 1                     CC1:O:C:C:C:1C(=O)NC1:C:C:C:C:C:1           4
# 2                                    CC(C)=CCCC(C)=CC=O           2
# 3     C1:C:C:C2:C(:C:1):C:C:C1:C:2:C:C:C2:C3:C:C:C:C...           3
# 4                                          C1:C:C:S:C:1           3
# ...                                                 ...         ...
# 1112                                    FC(F)(F)C(Cl)Br           5
# 1113                          CNC(=O)ON=C(SC)C(=O)N(C)C           2
# 1114                                  CCSCCSP(=S)(OC)OC           2
# 1115                                            CCC(C)C           5
# 1116        COP(=O)(OC)OC(=CCl)C1:C:C(Cl):C(Cl):C:C:1Cl           4
#
# [1117 rows x 2 columns]

# %%
output = pd.DataFrame(index=["Cluster 1",'Cluster 2','Cluster 3', "Cluster 4", "Cluster 5", "Cluster 6"]
                      , columns=['number of elements'])
output.loc['Cluster 0','number of elements'] = df_clusters[df_clusters["Cluster_ID"]==0].shape[0]
output.loc['Cluster 1','number of elements'] = df_clusters[df_clusters["Cluster_ID"]==1].shape[0]
output.loc['Cluster 2','number of elements'] = df_clusters[df_clusters["Cluster_ID"]==2].shape[0]
output.loc['Cluster 3','number of elements'] = df_clusters[df_clusters["Cluster_ID"]==3].shape[0]
output.loc['Cluster 4','number of elements'] = df_clusters[df_clusters["Cluster_ID"]==4].shape[0]
output.loc['Cluster 5','number of elements'] = df_clusters[df_clusters["Cluster_ID"]==5].shape[0]
output.loc['Cluster 6','number of elements'] = df_clusters[df_clusters["Cluster_ID"]==6].shape[0]

output
# Out:
#           number of elements
# Cluster 1                158
# Cluster 2                168
# Cluster 3                200
# Cluster 4                217
# Cluster 5                167
# Cluster 6                 54
# Cluster 0                153

# %%
s1 = silhouette_score(x_red, clustering.labels_, metric='euclidean')
c1 = calinski_harabasz_score(x_red, clustering.labels_)
d1 = davies_bouldin_score(x_red, clustering.labels_)

# %%
new_row = {'Time for UMAP & Clustering' : tf, 'Silhouette' : s1, 'CH score' : c1, 'DB score' : d1, "Number of Clusters" : 7, "Method" : "UMAP & Agglomerative Clustering", "All Molecules" : "Yes", "Outlier Cutoff" : outlier_cutoff}
df2 = df_metrics.append(new_row, ignore_index=True)
df2
# Out:
# /var/folders/_t/26vz4yhd2lqb2866qhkw8htm0000gn/T/ipykernel_3373/2100690640.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df_metrics.append(new_row, ignore_index=True)
#    Time for UMAP & Clustering  Silhouette     CH score  DB score  \
# 0                    2.942214    0.576074  1273.043059  0.567648
# 1                    7.052497    0.417009  1919.801801  0.802765
#
#    Number of Clusters                           Method  \
# 0                   6  UMAP & Agglomerative Clustering
# 1                   7  UMAP & Agglomerative Clustering
#
#                  All Molecules  Outlier Cutoff
# 0  Just non outliers molecules             0.5
# 1                          Yes             0.5
