# %% [markdown]
# ### Libraries

# %% [raw]
# This files use the "compund-annotation" dataset, using method from the "On the best way to Cluster NCI-60 Molecules" article

# %%
# !pip install joblib==1.2.0
# !pip install MolVS==0.1.1
# !pip install numpy==1.23.5
# !pip install pandas==1.5.2
# !pip install Pillow==9.3.0
# !pip install pynndescent==0.5.8
# !pip install python-dateutil==2.8.2
# !pip install pytz==2022.7
# !pip install rdkit==2022.9.3
# !pip install scikit-learn==1.2.0
# !pip install scipy==1.9.3
# !pip install six==1.16.0
# !pip install threadpoolctl==3.1.0
# !pip install tqdm==4.64.1
# !pip install umap-learn==0.5.3
# Out:
# Requirement already satisfied: joblib==1.2.0 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (1.2.0)
# Requirement already satisfied: MolVS==0.1.1 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (0.1.1)
# Requirement already satisfied: six in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from MolVS==0.1.1) (1.16.0)
# Requirement already satisfied: numpy==1.23.5 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (1.23.5)
# Requirement already satisfied: pandas==1.5.2 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from pandas==1.5.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from pandas==1.5.2) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from pandas==1.5.2) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas==1.5.2) (1.16.0)
# Requirement already satisfied: Pillow==9.3.0 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (9.3.0)
# Requirement already satisfied: pynndescent==0.5.8 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (0.5.8)
# Requirement already satisfied: scikit-learn>=0.18 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from pynndescent==0.5.8) (1.2.0)
# Requirement already satisfied: scipy>=1.0 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from pynndescent==0.5.8) (1.9.3)
# Requirement already satisfied: numba>=0.51.2 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from pynndescent==0.5.8) (0.57.0)
# Requirement already satisfied: llvmlite>=0.30 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from pynndescent==0.5.8) (0.40.0)
# Requirement already satisfied: joblib>=0.11 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from pynndescent==0.5.8) (1.2.0)
# Requirement already satisfied: numpy<1.25,>=1.21 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from numba>=0.51.2->pynndescent==0.5.8) (1.23.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.18->pynndescent==0.5.8) (3.1.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from python-dateutil==2.8.2) (1.16.0)
# Requirement already satisfied: pytz==2022.7 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (2022.7)
# Requirement already satisfied: rdkit==2022.9.3 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (2022.9.3)
# Requirement already satisfied: numpy in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from rdkit==2022.9.3) (1.23.5)
# Requirement already satisfied: Pillow in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from rdkit==2022.9.3) (9.3.0)
# Requirement already satisfied: scikit-learn==1.2.0 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.2.0) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.2.0) (1.9.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.2.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.2.0) (3.1.0)
# Requirement already satisfied: scipy==1.9.3 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (1.9.3)
# Requirement already satisfied: numpy<1.26.0,>=1.18.5 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from scipy==1.9.3) (1.23.5)
# Requirement already satisfied: six==1.16.0 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (1.16.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (3.1.0)
# Requirement already satisfied: tqdm==4.64.1 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (4.64.1)
# Requirement already satisfied: umap-learn==0.5.3 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (0.5.3)
# Requirement already satisfied: numpy>=1.17 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from umap-learn==0.5.3) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from umap-learn==0.5.3) (1.2.0)
# Requirement already satisfied: scipy>=1.0 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from umap-learn==0.5.3) (1.9.3)
# Requirement already satisfied: numba>=0.49 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from umap-learn==0.5.3) (0.57.0)
# Requirement already satisfied: pynndescent>=0.5 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from umap-learn==0.5.3) (0.5.8)
# Requirement already satisfied: tqdm in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from umap-learn==0.5.3) (4.64.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from numba>=0.49->umap-learn==0.5.3) (0.40.0)
# Requirement already satisfied: joblib>=0.11 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from pynndescent>=0.5->umap-learn==0.5.3) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mjolif/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22->umap-learn==0.5.3) (3.1.0)

# %%
from rdkit import RDLogger
from rdkit import Chem
from rdkit.Chem import SaltRemover
from molvs import Standardizer
from rdkit.Chem import AllChem
from rdkit import DataStructs

from time import time
import numpy as np
import pandas as pd
import umap
# Out:
# /Users/mjolif/anaconda3/lib/python3.11/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/mjolif/anaconda3/lib/python3.11/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/mjolif/anaconda3/lib/python3.11/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/mjolif/anaconda3/lib/python3.11/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import calinski_harabasz_score, davies_bouldin_score, silhouette_score

# %% [markdown]
# ### Data preprocessing

# %%
molecules = pd.read_csv("compound-annotation.csv", sep=",")
molecules = molecules[["SMILES"]]
molecules = molecules.drop_duplicates(subset=['SMILES'], ignore_index=True)
molecules = molecules[molecules["SMILES"].notna()]

n = molecules.shape[0]
new_index = []
new_index = list(range(n))

molecules.index = new_index

molecules
# Out:
#                                                   SMILES
# 0       CN(C)C(=O)CC1CC2(CCN(CC2)C(=O)N2CCCC2)Oc2ccccc12
# 1         Cc1c([nH]c2CC(CC(=O)c12)c1ccco1)C(=O)OCC1CCCO1
# 2                  CNC(=O)CN1CCC11CCN(C1)C(=O)c1ccn(C)n1
# 3             Cn1cc(cn1)N1CCC2(CCN(C2)C(=O)c2ccncc2)C1=O
# 4                  CC(C)CN1CC2CN(CC2C1)S(=O)(=O)c1ccccc1
# ...                                                  ...
# 47212  [Zn++].CCC(C)[C@H](N)C1=NCC(S1)C(=O)N[C@@H](CC...
# 47213  CCCNC(=O)[C@@H]1[C@@H](CO)[C@@H]2Cn3c(=O)c(ccc...
# 47214  C\C=C\c1ccc2[C@H]3N[C@H]([C@H](CO)[C@H]3Cn2c1=...
# 47215  CCN1[C@@H](C(=O)Nc2ccccc2)[C@H](CO)[C@H]2Cn3c(...
# 47216  C1[C@@H]([C@H]([C@@H]([C@H]([C@@H]1NC(=O)[C@H]...
#
# [47217 rows x 1 columns]

# %%
n = molecules.shape[0]
mol = []
mol1 = []



for k in range(n):
    m = Chem.MolFromSmiles(molecules['SMILES'][k])

    remover = SaltRemover.SaltRemover()  # remove salt
    m = remover.StripMol(m)
    s = Standardizer()  # standardize molecule
    m = s.standardize(m)

    mol.append(AllChem.GetMorganFingerprintAsBitVect(m, 2, nBits=1024))
    mol1.append(list(AllChem.GetMorganFingerprintAsBitVect(m, 2, nBits=1024)))

# %%
n = molecules.shape[0]
fps = mol
simis = []

for i in range(1, n):
    sims = DataStructs.BulkTanimotoSimilarity(fps[i], fps[:i])
    max_sims = np.max(np.array(sims))
    simis.append(max_sims)
simis.insert(0,1)
# Out:
# [1,
#  0.17045454545454544,
#  0.22666666666666666,
#  0.3088235294117647,
#  0.16417910447761194,
#  0.15294117647058825,
#  0.1686746987951807,
#  0.20512820512820512,
#  0.1917808219178082,
#  0.2077922077922078,
#  0.21518987341772153,
#  0.5294117647058824,
#  0.2857142857142857,
#  0.19736842105263158,
#  0.16071428571428573,
#  0.1935483870967742,
#  0.25,
#  0.21951219512195122,
#  0.26865671641791045,
#  0.26582278481012656,
#  0.28378378378378377,
#  0.17857142857142858,
#  0.24050632911392406,
#  0.3157894736842105,
#  0.20930232558139536,
#  0.23529411764705882,
#  0.3048780487804878,
#  0.2222222222222222,
#  0.24324324324324326,
#  0.3,
#  0.2571428571428571,
#  0.24285714285714285,
#  0.22093023255813954,
#  0.20212765957446807,
#  0.6507936507936508,
#  0.28846153846153844,
#  0.28205128205128205,
#  0.22988505747126436,
#  0.1917808219178082,
#  0.4084507042253521,
#  0.34146341463414637,
#  0.42105263157894735,
#  0.4716981132075472,
#  0.30434782608695654,
#  0.7894736842105263,
#  0.2191780821917808,
#  0.4262295081967213,
#  0.423728813559322,
#  0.6545454545454545,
#  0.3783783783783784,
#  0.5362318840579711,
#  0.3116883116883117,
#  0.5294117647058824,
#  0.3880597014925373,
#  0.37037037037037035,
#  0.7547169811320755,
#  0.7192982456140351,
#  0.7272727272727273,
#  0.6129032258064516,
#  0.4375,
#  0.4722222222222222,
#  0.44285714285714284,
#  0.43478260869565216,
#  0.44155844155844154,
#  0.4090909090909091,
#  0.46551724137931033,
#  0.2222222222222222,
#  0.5294117647058824,
#  0.5178571428571429,
#  0.4067796610169492,
#  0.4074074074074074,
#  0.46153846153846156,
#  0.3815789473684211,
#  0.5151515151515151,
#  0.4603174603174603,
#  0.6428571428571429,
#  0.7307692307692307,
#  0.234375,
#  0.3114754098360656,
#  0.4153846153846154,
#  0.4666666666666667,
#  0.5573770491803278,
#  0.43548387096774194,
#  0.3787878787878788,
#  0.4647887323943662,
#  0.6266666666666667,
#  0.3333333333333333,
#  0.4492753623188406,
#  0.2903225806451613,
#  0.5151515151515151,
#  0.38961038961038963,
#  0.5074626865671642,
#  0.3387096774193548,
#  0.625,
#  ...]

# %%
df_tanimoto = molecules.copy()
df_tanimoto['Tanimoto similarity'] = simis
df_tanimoto['outlier'] = np.where(df_tanimoto['Tanimoto similarity'] <= 0.5, True, False)
df_nonoutliers = df_tanimoto[df_tanimoto.loc[:, 'outlier'] == False]

n = df_nonoutliers.shape[0]
new_index = []
new_index = list(range(n))

df_nonoutliers.index = new_index


df_nonoutliers
# Out:
#                                                   SMILES  Tanimoto similarity  \
# 0       CN(C)C(=O)CC1CC2(CCN(CC2)C(=O)N2CCCC2)Oc2ccccc12             1.000000
# 1       C1CC(N(C1)C(=O)c1ccncc1)c1nnn2cc(ccc12)-c1ccccc1             0.529412
# 2      CN(C)C(=O)CC1CC2(CCN(CC2)C(=O)Nc2cccc(C)c2)Oc2...             0.650794
# 3                  CN(C)C1COC2(C1)CCN(CC2)S(=O)(=O)C1CC1             0.609756
# 4       CNC(=O)CC1CC2(CCN(CC2)C(=O)COc2ccccc2)Oc2ccccc12             0.562500
# ...                                                  ...                  ...
# 35409  CCC(=O)N1[C@H]([C@H](CO)[C@H]2Cn3c(ccc(\C=C\C)...             1.000000
# 35410  CCCNC(=O)[C@@H]1[C@@H](CO)[C@@H]2Cn3c(=O)c(ccc...             0.704225
# 35411  C\C=C\c1ccc2[C@H]3N[C@H]([C@H](CO)[C@H]3Cn2c1=...             0.700000
# 35412  CCN1[C@@H](C(=O)Nc2ccccc2)[C@H](CO)[C@H]2Cn3c(...             1.000000
# 35413  C1[C@@H]([C@H]([C@@H]([C@H]([C@@H]1NC(=O)[C@H]...             1.000000
#
#        outlier
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 35409    False
# 35410    False
# 35411    False
# 35412    False
# 35413    False
#
# [35414 rows x 3 columns]

# %%
n = df_nonoutliers.shape[0]
nonoutliers = []
nonoutliers1 = []

for k in range(n):
    m = Chem.MolFromSmiles(df_nonoutliers['SMILES'][k])

    remover = SaltRemover.SaltRemover()  # remove salt
    m = remover.StripMol(m)
    s = Standardizer()  # standardize molecule
    m = s.standardize(m)

    nonoutliers.append(AllChem.GetMorganFingerprintAsBitVect(m, 2, nBits=1024))
    nonoutliers1.append(list(AllChem.GetMorganFingerprintAsBitVect(m, 2, nBits=1024)))

# %% [markdown]
# ### Clustering

# %%
sample = nonoutliers1

# %%
t0 = time()
x_red = umap.UMAP(n_neighbors=100, min_dist=0.0, n_components=2, metric='jaccard',
                  random_state=42).fit_transform(sample)

clustering = AgglomerativeClustering(linkage='ward', n_clusters=7)
clustering.fit(x_red)
tf = time() - t0
# Out:
# /Users/mjolif/anaconda3/lib/python3.11/site-packages/umap/umap_.py:1802: UserWarning: gradient function is not yet implemented for jaccard distance metric; inverse_transform will be unavailable
#   warn(

# %%
def assign_cluster_id(df_data, cluster_id):
    df_data['Cluster_ID'] = cluster_id.labels_
    return df_data

# %%
df_clusters = assign_cluster_id(df_nonoutliers, clustering)
df_clusters
# Out:
# /var/folders/_t/26vz4yhd2lqb2866qhkw8htm0000gn/T/ipykernel_529/3228663661.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Cluster_ID'] = cluster_id.labels_
#                                                 smiles  Tanimoto similarity  \
# 0    N#CC(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O)C...             1.000000
# 1                                             CCCCCCCO             0.615385
# 2                             CCOP(=S)(OCC)SCSC(C)(C)C             0.607143
# 3                                             CCCCCCCI             0.615385
# 4                                           CCCCCC(C)O             0.941176
# ..                                                 ...                  ...
# 495                                      CC(=O)OCC(C)C             0.565217
# 496  ClC1:C:C:C(C2:C(Cl):C:C(Cl):C(Cl):C:2Cl):C(Cl)...             0.590909
# 497                      CC1:C:C:C:C([N+](=O)[O-]):C:1             0.695652
# 498                                  CCSCCSP(=S)(OC)OC             0.666667
# 499                                            CCC(C)C             0.545455
#
#      outlier  Cluster_ID
# 0      False           0
# 1      False           2
# 2      False           6
# 3      False           2
# 4      False           2
# ..       ...         ...
# 495    False           6
# 496    False           3
# 497    False           5
# 498    False           6
# 499    False           2
#
# [500 rows x 4 columns]

# %%
s1 = silhouette_score(x_red, clustering.labels_, metric='euclidean')
c1 = calinski_harabasz_score(x_red, clustering.labels_)
d1 = davies_bouldin_score(x_red, clustering.labels_)

# %%
df_metrics = pd.DataFrame(data=[[tf, s1, c1, d1, 7, "UMAP & Agglomerative Clustering", "Just non outliers molecules"]], columns=['Time for UMAP & Clustering', 'Silhouette', 'CH score', 'DB score', "Number of Clusters", "Method", "All Molecules"])
df_metrics
# Out:
#    Time for UMAP & Clustering  Silhouette      CH score  DB score  \
# 0                 2403.280006    0.506444  25371.072575  0.757673
#
#    Number of Clusters                           Method  \
# 0                   7  UMAP & Agglomerative Clustering
#
#                  All Molecules
# 0  Just non outliers molecules
